# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('churn.csv')

# %%
df.head()
# Out:
#    id_cliente  score_credito     pais sexo_biologico  idade  anos_de_cliente  \
# 0    15634602            619   França         Mulher     42                2
# 1    15647311            608  Espanha         Mulher     41                1
# 2    15619304            502   França         Mulher     42                8
# 3    15701354            699   França         Mulher     39                1
# 4    15737888            850  Espanha         Mulher     43                2
#
#        saldo  servicos_adquiridos  tem_cartao_credito  membro_ativo  \
# 0       0.00                    1                   1             1
# 1   83807.86                    1                   0             1
# 2  159660.80                    3                   1             0
# 3       0.00                    2                   0             0
# 4  125510.82                    1                   1             1
#
#    salario_estimado  churn
# 0         101348.88      1
# 1         112542.58      0
# ...

# %% [markdown]
# > **ANALISANDO TIPOS DE VARIAVEIS**
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_cliente           10000 non-null  int64
#  1   score_credito        10000 non-null  int64
#  2   pais                 10000 non-null  object
#  3   sexo_biologico       10000 non-null  object
#  4   idade                10000 non-null  int64
#  5   anos_de_cliente      10000 non-null  int64
#  6   saldo                10000 non-null  float64
#  7   servicos_adquiridos  10000 non-null  int64
#  8   tem_cartao_credito   10000 non-null  int64
#  9   membro_ativo         10000 non-null  int64
#  10  salario_estimado     10000 non-null  float64
#  11  churn                10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
df.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pais            10000 non-null  object
#  1   sexo_biologico  10000 non-null  object
# dtypes: object(2)
# memory usage: 156.4+ KB

# %%
df.select_dtypes(include=['float64', 'int64']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_cliente           10000 non-null  int64
#  1   score_credito        10000 non-null  int64
#  2   idade                10000 non-null  int64
#  3   anos_de_cliente      10000 non-null  int64
#  4   saldo                10000 non-null  float64
#  5   servicos_adquiridos  10000 non-null  int64
#  6   tem_cartao_credito   10000 non-null  int64
#  7   membro_ativo         10000 non-null  int64
#  8   salario_estimado     10000 non-null  float64
#  9   churn                10000 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 781.4 KB

# %% [markdown]
# > **EXPLORANDO VARIAVES CATEGORICA**
# ---

# %%
plt.figure(figsize=(10, 5))

p = sns.countplot(data=df,x='churn')
plt.title("Clientes que deixaram de usar o serviço ou não" )
plt.xlabel("Churn")
plt.ylabel("Quantidade")

for valor in p.patches:
    altura = valor.get_height()

    plt.text(valor.get_x() + valor.get_width() / 2,
             altura + 0.3, 
             str(int(altura)),
             ha ='center')

plt.show()

# %%
plt.figure(figsize=(10,6)) 

p = sns.countplot(data=df, x='pais', hue='churn')
plt.title("Distribuição de Churn por faixa de País")
plt.xlabel("País")
plt.ylabel("Quantidade")

for valor in p.patches:
    altura = valor.get_height()

    plt.text(valor.get_x() + valor.get_width() /2, 
            altura +0.5,
            str(int(altura)),
            ha='center')
    

plt.show()

# %%
plt.figure(figsize=(10,6)) 

p = sns.countplot(data=df, x='sexo_biologico', hue='churn')
plt.title("Distribuição de Churn por faixa Gênero")
plt.xlabel("sexo_biologico")
plt.ylabel("Quantidade")

for valor in p.patches:
    altura = valor.get_height()

    plt.text(valor.get_x() + valor.get_width() /2, 
            altura +0.5,
            str(int(altura)),
            ha='center')
    

plt.show()

# %%
plt.figure(figsize=(10,6)) 

p = sns.countplot(data=df, x='anos_de_cliente', hue='churn')
plt.title("Distribuição de Churn por tempo anos como cliente")
plt.xlabel("Anos")
plt.ylabel("Quantidade")

for valor in p.patches:
    altura = valor.get_height()

    plt.text(valor.get_x() + valor.get_width() /2, 
            altura +0.5,
            str(int(altura)),
            ha='center')
    

plt.show()

# %%
plt.figure(figsize=(10,6)) 

p = sns.countplot(data=df, x='servicos_adquiridos', hue='churn')
plt.title("Distribuição de Churn por produto adquirido")
plt.xlabel("Produto")
plt.ylabel("Quantidade")

for valor in p.patches:
    altura = valor.get_height()

    plt.text(valor.get_x() + valor.get_width() /2, 
            altura +0.5,
            str(int(altura)),
            ha='center')
    

plt.show()

# %%
plt.figure(figsize=(10,6)) 

p = sns.countplot(data=df, x='tem_cartao_credito', hue='churn')
plt.title("Distribuição de Churn por cartão de credito")
plt.xlabel("Cartão de credito")
plt.ylabel("Quantidade")

for valor in p.patches:
    altura = valor.get_height()

    plt.text(valor.get_x() + valor.get_width() /2, 
            altura +0.5,
            str(int(altura)),
            ha='center')
    

plt.show()

# %%
plt.figure(figsize=(10,6)) 

p = sns.countplot(data=df, x='membro_ativo', hue='churn')
plt.title("Distribuição de Churn por membro_ativo")
plt.xlabel("membro_ativo")
plt.ylabel("Quantidade")

for valor in p.patches:
    altura = valor.get_height()

    plt.text(valor.get_x() + valor.get_width() /2, 
            altura +0.5,
            str(int(altura)),
            ha='center')
    

plt.show()
